# %% [markdown]
# # Experiment to study the effect of standardisation

# %% [markdown]
# ## Define data directory
#
# A top level directory to store all the data for this experiment

# %%
dataDirName = '/home/yram0006/phd/chapter_2/workspace/mortality_data/missingness_experiment/'

# %% [markdown]
# ## Data Extraction

# %% [markdown]
# ### Extract data

# %%
import os


os.system(
    '''cd /superbugai-data/yash/chapter_1/workspace/EHRQC;'''
    +
    '''mkdir -p ''' + dataDirName + '''extract;'''
    +
    '''.venv/bin/python -m ehrqc.extract.ExtractCohort ''' + dataDirName + '''"extract/cohort_icd.csv" "omop_cdm" "icd";'''
    +
    '''.venv/bin/python -m ehrqc.extract.ExtractCohortData ''' + dataDirName + '''"extract/demographics_icd.csv" ''' + dataDirName + '''"extract/cohort_icd.csv" "omop_cdm" "demographics" "min";'''
    +
    '''.venv/bin/python -m ehrqc.extract.ExtractCohortData ''' + dataDirName + '''"extract/deaths.csv" ''' + dataDirName + '''"extract/cohort_icd.csv" "omop_cdm" "deaths" "min";'''
    +
    '''.venv/bin/python -m ehrqc.extract.ExtractCohortData ''' + dataDirName + '''"extract/vitals_min_icd.csv" ''' + dataDirName + '''"extract/cohort_icd.csv" "omop_cdm" "vitals" "min" -b=0 -a=72;'''
    +
    '''.venv/bin/python -m ehrqc.extract.ExtractCohortData ''' + dataDirName + '''"extract/vitals_max_icd.csv" ''' + dataDirName + '''"extract/cohort_icd.csv" "omop_cdm" "vitals" "max" -b=0 -a=72;'''
    +
    '''.venv/bin/python -m ehrqc.extract.ExtractCohortData ''' + dataDirName + '''"extract/vitals_avg_icd.csv" ''' + dataDirName + '''"extract/cohort_icd.csv" "omop_cdm" "vitals" "avg" -b=0 -a=72;'''
    +
    '''.venv/bin/python -m ehrqc.extract.ExtractCohortData ''' + dataDirName + '''"extract/vitals_stddev_icd.csv" ''' + dataDirName + '''"extract/cohort_icd.csv" "omop_cdm" "vitals" "stddev" -b=0 -a=72;'''
    +
    '''.venv/bin/python -m ehrqc.extract.ExtractCohortData ''' + dataDirName + '''"extract/vitals_first_icd.csv" ''' + dataDirName + '''"extract/cohort_icd.csv" "omop_cdm" "vitals" "first" -b=0 -a=72;'''
    +
    '''.venv/bin/python -m ehrqc.extract.ExtractCohortData ''' + dataDirName + '''"extract/vitals_last_icd.csv" ''' + dataDirName + '''"extract/cohort_icd.csv" "omop_cdm" "vitals" "last" -b=0 -a=72;'''
    +
    '''.venv/bin/python -m ehrqc.extract.ExtractCohortData ''' + dataDirName + '''"extract/lab_measurements_min_icd.csv" ''' + dataDirName + '''"extract/cohort_icd.csv" "omop_cdm" "lab_measurements" "min" -b=0 -a=72;'''
    +
    '''.venv/bin/python -m ehrqc.extract.ExtractCohortData ''' + dataDirName + '''"extract/lab_measurements_max_icd.csv" ''' + dataDirName + '''"extract/cohort_icd.csv" "omop_cdm" "lab_measurements" "max" -b=0 -a=72;'''
    +
    '''.venv/bin/python -m ehrqc.extract.ExtractCohortData ''' + dataDirName + '''"extract/lab_measurements_avg_icd.csv" ''' + dataDirName + '''"extract/cohort_icd.csv" "omop_cdm" "lab_measurements" "avg" -b=0 -a=72;'''
    +
    '''.venv/bin/python -m ehrqc.extract.ExtractCohortData ''' + dataDirName + '''"extract/lab_measurements_stddev_icd.csv" ''' + dataDirName + '''"extract/cohort_icd.csv" "omop_cdm" "lab_measurements" "stddev" -b=0 -a=72;'''
    +
    '''.venv/bin/python -m ehrqc.extract.ExtractCohortData ''' + dataDirName + '''"extract/lab_measurements_first_icd.csv" ''' + dataDirName + '''"extract/cohort_icd.csv" "omop_cdm" "lab_measurements" "first" -b=0 -a=72;'''
    +
    '''.venv/bin/python -m ehrqc.extract.ExtractCohortData ''' + dataDirName + '''"extract/lab_measurements_last_icd.csv" ''' + dataDirName + '''"extract/cohort_icd.csv" "omop_cdm" "lab_measurements" "last" -b=0 -a=72;'''
    )
# Out:
# 2023-09-23 13:37:42,462 - EHRQC - INFO - Parsing command line arguments
# 2023-09-23 13:37:42,463 - EHRQC - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/mortality_data/missingness_experiment/extract/cohort_icd.csv
# 2023-09-23 13:37:42,463 - EHRQC - INFO - args.schema_name: omop_cdm
# 2023-09-23 13:37:42,463 - EHRQC - INFO - args.cohort_type: icd
# 2023-09-23 13:37:43,607 - EHRQC - INFO - extracting data
# /superbugai-data/yash/chapter_1/workspace/EHRQC/.venv/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# 2023-09-23 13:37:46,236 - EHRQC - INFO - Saving raw data to file
# 2023-09-23 13:37:48,040 - EHRQC - INFO - Parsing command line arguments
# ...

# %% [markdown]
# ### Read extracted files

# %%
import pandas as pd

demographics =  pd.read_csv(dataDirName + "extract/demographics_icd.csv")
vitals_min =  pd.read_csv(dataDirName + "extract/vitals_min_icd.csv")
vitals_max =  pd.read_csv(dataDirName + "extract/vitals_max_icd.csv")
vitals_avg =  pd.read_csv(dataDirName + "extract/vitals_avg_icd.csv")
vitals_stddev =  pd.read_csv(dataDirName + "extract/vitals_stddev_icd.csv")
vitals_first =  pd.read_csv(dataDirName + "extract/vitals_first_icd.csv")
vitals_last =  pd.read_csv(dataDirName + "extract/vitals_last_icd.csv")
lab_measurements_min =  pd.read_csv(dataDirName + "extract/lab_measurements_min_icd.csv")
lab_measurements_max =  pd.read_csv(dataDirName + "extract/lab_measurements_max_icd.csv")
lab_measurements_avg =  pd.read_csv(dataDirName + "extract/lab_measurements_avg_icd.csv")
lab_measurements_stddev =  pd.read_csv(dataDirName + "extract/lab_measurements_stddev_icd.csv")
lab_measurements_first =  pd.read_csv(dataDirName + "extract/lab_measurements_first_icd.csv")
lab_measurements_last =  pd.read_csv(dataDirName + "extract/lab_measurements_last_icd.csv")

# %% [markdown]
# ### Display counts post extraction

# %%
demographics.shape
# Out:
# (12241, 4)

# %%
vitals_min.shape, vitals_max.shape, vitals_avg.shape, vitals_stddev.shape, vitals_first.shape, vitals_last.shape
# Out:
# ((5184, 11), (5184, 11), (5184, 11), (5184, 11), (5184, 11), (5184, 11))

# %%
lab_measurements_min.shape, lab_measurements_max.shape, lab_measurements_avg.shape, lab_measurements_stddev.shape, lab_measurements_first.shape, lab_measurements_last.shape
# Out:
# ((9847, 30), (9847, 30), (9847, 30), (9847, 30), (9847, 30), (9847, 30))

# %% [markdown]
# ## Remove attributes with low coverage
#
# Removing attributes where the attributes have values that are missing in more than 25 % of the cases

# %% [markdown]
# ### Drop columns with low coverage

# %%
for p in [0.2, 0.4, 0.5, 0.6, 0.7]:
    print(p)
# Out:
# 0.2
# 0.4
# 0.5
# 0.6
# 0.7

# %%
import os


# for p in range(20, 100, 5):
for p in [0.2, 0.4, 0.5, 0.6, 0.7]:
    os.system(
        '''cd /superbugai-data/yash/chapter_1/workspace/EHRQC;'''
        +
        '''mkdir -p ''' + dataDirName + str(p) + '''_dropped;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Coverage ''' + dataDirName + '''extract/demographics_icd.csv 10 person_id -d -p 0 -sp ''' + dataDirName + str(p) + '''_dropped;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Coverage ''' + dataDirName + '''extract/deaths.csv 10 person_id -d -p 100 -sp ''' + dataDirName + str(p) + '''_dropped;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Coverage ''' + dataDirName + '''extract/vitals_min_icd.csv 10 person_id -d -p ''' + str(p) + ''' -sp ''' + dataDirName + str(p) + '''_dropped;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Coverage ''' + dataDirName + '''extract/vitals_max_icd.csv 10 person_id -d -p ''' + str(p) + ''' -sp ''' + dataDirName + str(p) + '''_dropped;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Coverage ''' + dataDirName + '''extract/vitals_avg_icd.csv 10 person_id -d -p ''' + str(p) + ''' -sp ''' + dataDirName + str(p) + '''_dropped;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Coverage ''' + dataDirName + '''extract/vitals_stddev_icd.csv 10 person_id -d -p ''' + str(p) + ''' -sp ''' + dataDirName + str(p) + '''_dropped;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Coverage ''' + dataDirName + '''extract/vitals_first_icd.csv 10 person_id -d -p ''' + str(p) + ''' -sp ''' + dataDirName + str(p) + '''_dropped;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Coverage ''' + dataDirName + '''extract/vitals_last_icd.csv 10 person_id -d -p ''' + str(p) + ''' -sp ''' + dataDirName + str(p) + '''_dropped;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Coverage ''' + dataDirName + '''extract/lab_measurements_min_icd.csv 10 person_id -d -p ''' + str(p) + ''' -sp ''' + dataDirName + str(p) + '''_dropped;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Coverage ''' + dataDirName + '''extract/lab_measurements_max_icd.csv 10 person_id -d -p ''' + str(p) + ''' -sp ''' + dataDirName + str(p) + '''_dropped;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Coverage ''' + dataDirName + '''extract/lab_measurements_avg_icd.csv 10 person_id -d -p ''' + str(p) + ''' -sp ''' + dataDirName + str(p) + '''_dropped;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Coverage ''' + dataDirName + '''extract/lab_measurements_stddev_icd.csv 10 person_id -d -p ''' + str(p) + ''' -sp ''' + dataDirName + str(p) + '''_dropped;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Coverage ''' + dataDirName + '''extract/lab_measurements_first_icd.csv 10 person_id -d -p ''' + str(p) + ''' -sp ''' + dataDirName + str(p) + '''_dropped;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Coverage ''' + dataDirName + '''extract/lab_measurements_last_icd.csv 10 person_id -d -p ''' + str(p) + ''' -sp ''' + dataDirName + str(p) + '''_dropped;'''
        )
# Out:
# 2023-09-24 07:49:32,418 - Anomalies - INFO - Parsing command line arguments
# 2023-09-24 07:49:32,419 - Anomalies - INFO - Start!!
# 2023-09-24 07:49:32,419 - Anomalies - INFO - args.source_file: /home/yram0006/phd/chapter_2/workspace/mortality_data/missingness_experiment/extract/demographics_icd.csv
# 2023-09-24 07:49:32,419 - Anomalies - INFO - args.chunksize: 10
# 2023-09-24 07:49:32,419 - Anomalies - INFO - args.id_columns: ['person_id']
# 2023-09-24 07:49:32,419 - Anomalies - INFO - args.drop: True
# 2023-09-24 07:49:32,419 - Anomalies - INFO - args.percentage: 0.0
# 2023-09-24 07:49:32,419 - Anomalies - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/mortality_data/missingness_experiment/0.2_dropped
# 2023-09-24 07:49:32,419 - Anomalies - INFO - Calculating Missingnes
# 2023-09-24 07:49:37,444 - Anomalies - INFO - Missingness Report
# 2023-09-24 07:49:37,447 - Anomalies - INFO -
#
#   column_name  missing_count  total_count  percentage_missing
# ...

# %% [markdown]
# ## Missing data imputation
#
# Data imputation is performed for all the missing data

# %% [markdown]
# ### Impute missing data

# %%
import os


# for p in range(20, 100, 5):
for p in [0.2, 0.4, 0.5, 0.6, 0.7]:
    os.system(
        '''cd /superbugai-data/yash/chapter_1/workspace/EHRQC;'''
        +
        '''mkdir -p ''' + dataDirName + str(p) + '''_imputed;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Impute "impute" "''' + dataDirName + str(p) + '''_dropped/vitals_min_icd_dropped.csv"  -sp="''' + dataDirName + str(p) + '''_imputed/vitals_min_icd.csv" -a="miss_forest";'''
        +
        '''.venv/bin/python -m ehrqc.qc.Impute "impute" "''' + dataDirName + str(p) + '''_dropped/vitals_max_icd_dropped.csv"  -sp="''' + dataDirName + str(p) + '''_imputed/vitals_max_icd.csv" -a="miss_forest";'''
        +
        '''.venv/bin/python -m ehrqc.qc.Impute "impute" "''' + dataDirName + str(p) + '''_dropped/vitals_avg_icd_dropped.csv"  -sp="''' + dataDirName + str(p) + '''_imputed/vitals_avg_icd.csv" -a="miss_forest";'''
        +
        '''.venv/bin/python -m ehrqc.qc.Impute "impute" "''' + dataDirName + str(p) + '''_dropped/vitals_stddev_icd_dropped.csv"  -sp="''' + dataDirName + str(p) + '''_imputed/vitals_stddev_icd.csv" -a="miss_forest";'''
        +
        '''.venv/bin/python -m ehrqc.qc.Impute "impute" "''' + dataDirName + str(p) + '''_dropped/vitals_first_icd_dropped.csv"  -sp="''' + dataDirName + str(p) + '''_imputed/vitals_first_icd.csv" -a="miss_forest";'''
        +
        '''.venv/bin/python -m ehrqc.qc.Impute "impute" "''' + dataDirName + str(p) + '''_dropped/vitals_last_icd_dropped.csv"  -sp="''' + dataDirName + str(p) + '''_imputed/vitals_last_icd.csv" -a="miss_forest";'''
        +
        '''.venv/bin/python -m ehrqc.qc.Impute "impute" "''' + dataDirName + str(p) + '''_dropped/lab_measurements_min_icd_dropped.csv"  -sp="''' + dataDirName + str(p) + '''_imputed/lab_measurements_min_icd.csv" -a="miss_forest";'''
        +
        '''.venv/bin/python -m ehrqc.qc.Impute "impute" "''' + dataDirName + str(p) + '''_dropped/lab_measurements_max_icd_dropped.csv"  -sp="''' + dataDirName + str(p) + '''_imputed/lab_measurements_max_icd.csv" -a="miss_forest";'''
        +
        '''.venv/bin/python -m ehrqc.qc.Impute "impute" "''' + dataDirName + str(p) + '''_dropped/lab_measurements_avg_icd_dropped.csv"  -sp="''' + dataDirName + str(p) + '''_imputed/lab_measurements_avg_icd.csv" -a="miss_forest";'''
        +
        '''.venv/bin/python -m ehrqc.qc.Impute "impute" "''' + dataDirName + str(p) + '''_dropped/lab_measurements_stddev_icd_dropped.csv"  -sp="''' + dataDirName + str(p) + '''_imputed/lab_measurements_stddev_icd.csv" -a="miss_forest";'''
        +
        '''.venv/bin/python -m ehrqc.qc.Impute "impute" "''' + dataDirName + str(p) + '''_dropped/lab_measurements_first_icd_dropped.csv"  -sp="''' + dataDirName + str(p) + '''_imputed/lab_measurements_first_icd.csv" -a="miss_forest";'''
        +
        '''.venv/bin/python -m ehrqc.qc.Impute "impute" "''' + dataDirName + str(p) + '''_dropped/lab_measurements_last_icd_dropped.csv"  -sp="''' + dataDirName + str(p) + '''_imputed/lab_measurements_last_icd.csv" -a="miss_forest";'''
        )
# Out:
# 2023-09-24 07:54:47,881 - EHRQC - INFO - Parsing command line arguments
# 2023-09-24 07:54:47,882 - EHRQC - INFO - args.action: impute
# 2023-09-24 07:54:47,882 - EHRQC - INFO - args.source_path: /home/yram0006/phd/chapter_2/workspace/mortality_data/missingness_experiment/0.2_dropped/vitals_min_icd_dropped.csv
# 2023-09-24 07:54:47,882 - EHRQC - INFO - args.percentage: None
# 2023-09-24 07:54:47,882 - EHRQC - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/mortality_data/missingness_experiment/0.2_imputed/vitals_min_icd.csv
# 2023-09-24 07:54:47,882 - EHRQC - INFO - args.algorithm: miss_forest
# Iteration: 0
# Iteration: 1
# Iteration: 2
# 2023-09-24 07:54:51,309 - EHRQC - INFO - Done!!
# 2023-09-24 07:54:52,998 - EHRQC - INFO - Parsing command line arguments
# 2023-09-24 07:54:52,999 - EHRQC - INFO - args.action: impute
# ...

# %% [markdown]
# ## Outlier removal using IRT

# %% [markdown]
# ### Remove outliers

# %%
import os


# for p in range(20, 100, 5):
for p in [0.2, 0.4, 0.5, 0.6, 0.7]:
    os.system(
        '''cd /superbugai-data/yash/chapter_1/workspace/EHRQC;'''
        +
        '''mkdir -p ''' + dataDirName + str(p) + '''_outlier_removal;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Anomalies ''' + dataDirName + str(p) + '''_imputed/vitals_min_icd.csv ''' + dataDirName + str(p) + '''_outlier_removal/ vitals_min_icd -co;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Anomalies ''' + dataDirName + str(p) + '''_imputed/vitals_max_icd.csv ''' + dataDirName + str(p) + '''_outlier_removal/ vitals_max_icd -co;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Anomalies ''' + dataDirName + str(p) + '''_imputed/vitals_avg_icd.csv ''' + dataDirName + str(p) + '''_outlier_removal/ vitals_avg_icd -co;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Anomalies ''' + dataDirName + str(p) + '''_imputed/vitals_stddev_icd.csv ''' + dataDirName + str(p) + '''_outlier_removal/ vitals_stddev_icd -co;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Anomalies ''' + dataDirName + str(p) + '''_imputed/vitals_first_icd.csv ''' + dataDirName + str(p) + '''_outlier_removal/ vitals_first_icd -co;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Anomalies ''' + dataDirName + str(p) + '''_imputed/vitals_last_icd.csv ''' + dataDirName + str(p) + '''_outlier_removal/ vitals_last_icd -co;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Anomalies ''' + dataDirName + str(p) + '''_imputed/lab_measurements_min_icd.csv ''' + dataDirName + str(p) + '''_outlier_removal/ lab_measurements_min_icd -co;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Anomalies ''' + dataDirName + str(p) + '''_imputed/lab_measurements_max_icd.csv ''' + dataDirName + str(p) + '''_outlier_removal/ lab_measurements_max_icd -co;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Anomalies ''' + dataDirName + str(p) + '''_imputed/lab_measurements_avg_icd.csv ''' + dataDirName + str(p) + '''_outlier_removal/ lab_measurements_avg_icd -co;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Anomalies ''' + dataDirName + str(p) + '''_imputed/lab_measurements_stddev_icd.csv ''' + dataDirName + str(p) + '''_outlier_removal/ lab_measurements_stddev_icd -co;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Anomalies ''' + dataDirName + str(p) + '''_imputed/lab_measurements_first_icd.csv ''' + dataDirName + str(p) + '''_outlier_removal/ lab_measurements_first_icd -co;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Anomalies ''' + dataDirName + str(p) + '''_imputed/lab_measurements_last_icd.csv ''' + dataDirName + str(p) + '''_outlier_removal/ lab_measurements_last_icd -co;'''
        )
# Out:
# 2023-09-24 08:05:43,915 - Anomalies - INFO - Parsing command line arguments
# 2023-09-24 08:05:43,916 - Anomalies - INFO - Start!!
# 2023-09-24 08:05:43,916 - Anomalies - INFO - args.source_path: /home/yram0006/phd/chapter_2/workspace/mortality_data/missingness_experiment/0.2_imputed/vitals_min_icd.csv
# 2023-09-24 08:05:43,916 - Anomalies - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/mortality_data/missingness_experiment/0.2_outlier_removal/
# 2023-09-24 08:05:43,916 - Anomalies - INFO - args.save_prefix: vitals_min_icd
# 2023-09-24 08:05:43,916 - Anomalies - INFO - args.detect_missing: False
# 2023-09-24 08:05:43,916 - Anomalies - INFO - args.detect_outliers: False
# 2023-09-24 08:05:43,916 - Anomalies - INFO - args.detect_errors: False
# 2023-09-24 08:05:43,916 - Anomalies - INFO - args.detect_inconsistencies: False
# 2023-09-24 08:05:43,916 - Anomalies - INFO - args.correct_missing: False
# ...

# %% [markdown]
# ## Create standardised data matrix

# %% [markdown]
# ### Standardise the data

# %%
import os


# for p in range(20, 100, 5):
for p in [0.2, 0.4, 0.5, 0.6, 0.7]:
    os.system(
        '''cd /superbugai-data/yash/chapter_1/workspace/EHRQC;'''
        +
        '''mkdir -p ''' + dataDirName + str(p) + '''_standardised;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Standardise ''' + dataDirName + str(p) + '''_outlier_removal/vitals_min_icd_corrected.csv ''' + dataDirName + str(p) + '''_standardised/vitals_min_icd.csv -c `head -1 ''' + dataDirName + str(p) + '''_outlier_removal/vitals_min_icd_corrected.csv | sed -e 's/person_id,//g'`;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Standardise ''' + dataDirName + str(p) + '''_outlier_removal/vitals_max_icd_corrected.csv ''' + dataDirName + str(p) + '''_standardised/vitals_max_icd.csv -c `head -1 ''' + dataDirName + str(p) + '''_outlier_removal/vitals_max_icd_corrected.csv | sed -e 's/person_id,//g'`;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Standardise ''' + dataDirName + str(p) + '''_outlier_removal/vitals_avg_icd_corrected.csv ''' + dataDirName + str(p) + '''_standardised/vitals_avg_icd.csv -c  `head -1 ''' + dataDirName + str(p) + '''_outlier_removal/vitals_avg_icd_corrected.csv | sed -e 's/person_id,//g'`;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Standardise ''' + dataDirName + str(p) + '''_outlier_removal/vitals_stddev_icd_corrected.csv ''' + dataDirName + str(p) + '''_standardised/vitals_stddev_icd.csv -c  `head -1 ''' + dataDirName + str(p) + '''_outlier_removal/vitals_stddev_icd_corrected.csv | sed -e 's/person_id,//g'`;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Standardise ''' + dataDirName + str(p) + '''_outlier_removal/vitals_first_icd_corrected.csv ''' + dataDirName + str(p) + '''_standardised/vitals_first_icd.csv -c  `head -1 ''' + dataDirName + str(p) + '''_outlier_removal/vitals_first_icd_corrected.csv | sed -e 's/person_id,//g'`;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Standardise ''' + dataDirName + str(p) + '''_outlier_removal/vitals_last_icd_corrected.csv ''' + dataDirName + str(p) + '''_standardised/vitals_last_icd.csv -c  `head -1 ''' + dataDirName + str(p) + '''_outlier_removal/vitals_last_icd_corrected.csv | sed -e 's/person_id,//g'`;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Standardise ''' + dataDirName + str(p) + '''_outlier_removal/lab_measurements_min_icd_corrected.csv ''' + dataDirName + str(p) + '''_standardised/lab_measurements_min_icd.csv -c  `head -1 ''' + dataDirName + str(p) + '''_outlier_removal/lab_measurements_min_icd_corrected.csv | sed -e 's/person_id,//g'`;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Standardise ''' + dataDirName + str(p) + '''_outlier_removal/lab_measurements_max_icd_corrected.csv ''' + dataDirName + str(p) + '''_standardised/lab_measurements_max_icd.csv -c `head -1 ''' + dataDirName + str(p) + '''_outlier_removal/lab_measurements_max_icd_corrected.csv | sed -e 's/person_id,//g'`;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Standardise ''' + dataDirName + str(p) + '''_outlier_removal/lab_measurements_avg_icd_corrected.csv ''' + dataDirName + str(p) + '''_standardised/lab_measurements_avg_icd.csv -c `head -1 ''' + dataDirName + str(p) + '''_outlier_removal/lab_measurements_avg_icd_corrected.csv | sed -e 's/person_id,//g'`;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Standardise ''' + dataDirName + str(p) + '''_outlier_removal/lab_measurements_stddev_icd_corrected.csv ''' + dataDirName + str(p) + '''_standardised/lab_measurements_stddev_icd.csv -c `head -1 ''' + dataDirName + str(p) + '''_outlier_removal/lab_measurements_stddev_icd_corrected.csv | sed -e 's/person_id,//g'`;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Standardise ''' + dataDirName + str(p) + '''_outlier_removal/lab_measurements_first_icd_corrected.csv ''' + dataDirName + str(p) + '''_standardised/lab_measurements_first_icd.csv -c `head -1 ''' + dataDirName + str(p) + '''_outlier_removal/lab_measurements_first_icd_corrected.csv | sed -e 's/person_id,//g'`;'''
        +
        '''.venv/bin/python -m ehrqc.qc.Standardise ''' + dataDirName + str(p) + '''_outlier_removal/lab_measurements_last_icd_corrected.csv ''' + dataDirName + str(p) + '''_standardised/lab_measurements_last_icd.csv -c `head -1 ''' + dataDirName + str(p) + '''_outlier_removal/lab_measurements_last_icd_corrected.csv | sed -e 's/person_id,//g'`;'''
        )
# Out:
# 2023-09-24 08:20:26,489 - EHRQC - INFO - Parsing command line arguments
# 2023-09-24 08:20:26,490 - EHRQC - INFO - args.source_path: /home/yram0006/phd/chapter_2/workspace/mortality_data/missingness_experiment/0.2_outlier_removal/vitals_min_icd_corrected.csv
# 2023-09-24 08:20:26,490 - EHRQC - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/mortality_data/missingness_experiment/0.2_standardised/vitals_min_icd.csv
# 2023-09-24 08:20:26,490 - EHRQC - INFO - args.columns: heartrate,meanbp,resprate,spo2
# 2023-09-24 08:20:26,490 - EHRQC - INFO - args.scaler_save_path: None
# 2023-09-24 08:20:26,522 - EHRQC - INFO - Done!!
# 2023-09-24 08:20:27,254 - EHRQC - INFO - Parsing command line arguments
# 2023-09-24 08:20:27,256 - EHRQC - INFO - args.source_path: /home/yram0006/phd/chapter_2/workspace/mortality_data/missingness_experiment/0.2_outlier_removal/vitals_max_icd_corrected.csv
# ...

# %% [markdown]
# ## Create data matrix

# %%
import os
import pandas as pd


for p in range(20, 100, 5):
# for p in [0.2, 0.4, 0.5, 0.6, 0.7]:
    demographics =  pd.read_csv(dataDirName + 'extract/demographics_icd.csv')
    deaths =  pd.read_csv(dataDirName + 'extract/deaths.csv')
    vitals_min =  pd.read_csv(dataDirName + str(p) + '_standardised/vitals_min_icd.csv')
    vitals_max =  pd.read_csv(dataDirName + str(p) + '_standardised/vitals_max_icd.csv')
    vitals_avg =  pd.read_csv(dataDirName + str(p) + '_standardised/vitals_avg_icd.csv')
    vitals_stddev =  pd.read_csv(dataDirName + str(p) + '_standardised/vitals_stddev_icd.csv')
    vitals_first =  pd.read_csv(dataDirName + str(p) + '_standardised/vitals_first_icd.csv')
    vitals_last =  pd.read_csv(dataDirName + str(p) + '_standardised/vitals_last_icd.csv')
    lab_measurements_min =  pd.read_csv(dataDirName + str(p) + '_standardised/lab_measurements_min_icd.csv')
    lab_measurements_max =  pd.read_csv(dataDirName + str(p) + '_standardised/lab_measurements_max_icd.csv')
    lab_measurements_avg =  pd.read_csv(dataDirName + str(p) + '_standardised/lab_measurements_avg_icd.csv')
    lab_measurements_stddev =  pd.read_csv(dataDirName + str(p) + '_standardised/lab_measurements_stddev_icd.csv')
    lab_measurements_first =  pd.read_csv(dataDirName + str(p) + '_standardised/lab_measurements_first_icd.csv')
    lab_measurements_last =  pd.read_csv(dataDirName + str(p) + '_standardised/lab_measurements_last_icd.csv')

    demographics['gender'] = demographics.gender.apply(lambda x: 1 if(x == 'M') else 0)

    demographics['ethnicity_WHITE'] = demographics.ethnicity.apply(lambda x: 1 if(x == 'WHITE') else 0)
    demographics['ethnicity_BLACK'] = demographics.ethnicity.apply(lambda x: 1 if(x == 'BLACK/AFRICAN AMERICAN') else 0)
    demographics['ethnicity_UNKNOWN'] = demographics.ethnicity.apply(lambda x: 1 if(x == 'UNKNOWN') else 0)
    demographics['ethnicity_OTHER'] = demographics.ethnicity.apply(lambda x: 1 if(x == 'OTHER') else 0)
    demographics['ethnicity_HISPANIC'] = demographics.ethnicity.apply(lambda x: 1 if(x == 'HISPANIC/LATINO') else 0)
    demographics['ethnicity_ASIAN'] = demographics.ethnicity.apply(lambda x: 1 if(x == 'ASIAN') else 0)
    demographics['ethnicity_UNABLE_TO_OBTAIN'] = demographics.ethnicity.apply(lambda x: 1 if(x == 'UNABLE TO OBTAIN') else 0)
    demographics['ethnicity_AMERICAN_INDIAN'] = demographics.ethnicity.apply(lambda x: 1 if(x == 'AMERICAN INDIAN/ALASKA NATIVE') else 0)

    demographics.drop(columns='ethnicity', inplace=True)

    mergedDf = pd.merge(demographics, deaths, how='inner', on='person_id')
    mergedDf = pd.merge(mergedDf, vitals_min.add_suffix('_min'), how='inner', left_on='person_id', right_on='person_id_min')
    mergedDf = pd.merge(mergedDf, vitals_max.add_suffix('_max'), how='inner', left_on='person_id', right_on='person_id_max')
    mergedDf = pd.merge(mergedDf, vitals_avg.add_suffix('_avg'), how='inner', left_on='person_id', right_on='person_id_avg')
    mergedDf = pd.merge(mergedDf, vitals_stddev.add_suffix('_stddev'), how='inner', left_on='person_id', right_on='person_id_stddev')
    mergedDf = pd.merge(mergedDf, vitals_first.add_suffix('_first'), how='inner', left_on='person_id', right_on='person_id_first')
    mergedDf = pd.merge(mergedDf, vitals_last.add_suffix('_last'), how='inner', left_on='person_id', right_on='person_id_last')
    mergedDf = mergedDf.drop(['person_id_min', 'person_id_max', 'person_id_avg', 'person_id_stddev', 'person_id_first', 'person_id_last'], axis = 1)
    mergedDf = pd.merge(mergedDf, lab_measurements_min.add_suffix('_min'), how='inner', left_on='person_id', right_on='person_id_min')
    mergedDf = pd.merge(mergedDf, lab_measurements_max.add_suffix('_max'), how='inner', left_on='person_id', right_on='person_id_max')
    mergedDf = pd.merge(mergedDf, lab_measurements_avg.add_suffix('_avg'), how='inner', left_on='person_id', right_on='person_id_avg')
    mergedDf = pd.merge(mergedDf, lab_measurements_stddev.add_suffix('_stddev'), how='inner', left_on='person_id', right_on='person_id_stddev')
    mergedDf = pd.merge(mergedDf, lab_measurements_first.add_suffix('_first'), how='inner', left_on='person_id', right_on='person_id_first')
    mergedDf = pd.merge(mergedDf, lab_measurements_last.add_suffix('_last'), how='inner', left_on='person_id', right_on='person_id_last')
    mergedDf = mergedDf.drop(['person_id_min', 'person_id_max', 'person_id_avg', 'person_id_stddev', 'person_id_first', 'person_id_last'], axis = 1)

    os.system(
        '''mkdir -p ''' + dataDirName + '''data_matrix;'''
    )

    mergedDf.to_csv(dataDirName + 'data_matrix/data_matrix_standardised_' + str(p) + '.csv', index=False)
